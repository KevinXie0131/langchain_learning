# %% [markdown]
# # 1、获取大模型

# %%
#导入 dotenv 库的 load_dotenv 函数，用于加载环境变量文件（.env）中的配置
import dotenv
from langchain_openai import ChatOpenAI
import os

dotenv.load_dotenv()  #加载当前目录下的 .env 文件

os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")
os.environ['OPENAI_BASE_URL'] = os.getenv("OPENAI_BASE_URL")

# 创建大模型实例
llm = ChatOpenAI(model="gpt-4o-mini")  # 默认使用 gpt-3.5-turbo

# 直接提供问题，并调用llm
response = llm.invoke("什么是大模型？")
print(response)
# Out:
# content='大模型（Large Model）通常指的是具有大量参数和复杂结构的机器学习模型，特别是在自然语言处理（NLP）、计算机视觉等领域中广泛使用的深度学习模型。这类模型能够处理大规模的数据集，因此具备更强的学习和表达能力。\n\n以下是大模型的一些关键特点：\n\n1. **规模庞大**：大模型通常包含数亿甚至数十亿个参数，这使得它们能够捕捉复杂的模式和特征。\n\n2. **数据驱动**：大模型需要大量的数据进行训练，以便能够学习到有用的特征和规律。通常情况下，它们对训练数据的依赖性较强。\n\n3. **预训练和微调**：大模型常常经过预训练（在大规模数据上进行训练），然后进行微调（在特定任务或数据集上进行进一步训练），以实现针对特定应用的优化。\n\n4. **强大的泛化能力**：由于训练时使用了大量的数据和丰富的结构，大模型通常能够在未见过的样本上表现出较好的泛化能力。\n\n5. **计算资源需求高**：训练和推理大模型通常需要大量的计算资源，包括高性能的GPU或TPU。\n\n一些著名的大模型例子包括OpenAI的GPT系列、Google的BERT和T5、Meta的LLAMA等。这些模型在多个NLP任务中都展现出了卓越的性能。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 319, 'prompt_tokens': 12, 'total_tokens': 331, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8bbc38b4db', 'id': 'chat
# ...

# %%
from openai import OpenAI

client = OpenAI(
  api_key="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"
)

response = client.responses.create(
  model="gpt-4o-mini",
  input="write a poem about blue sky",
  store=True,
)

print(response.output_text);
# Out:
# Beneath the dome of endless blue,
# A canvas brushed with azure hue,
# Where cotton clouds softly drift and play,
# In the golden light of a sunlit day.
#
# Whispers of wind dance through the air,
# Carrying dreams without a care,
# Birds weave arcs of unbound flight,
# In the tranquil embrace of the morning light.
#
# Mountains stand tall, in shadows they bask,
# While oceans reflect the sky’s azure mask,
# Each hue a promise, clear and bright,
# A symphony of blue, pure delight.
#
# The day wears on, as the sun takes its bow,
# Painting the horizon, a fiery vow,
# Yet in the twilight, the memories cling,
# Of time spent beneath that blue sky of spring.
#
# So let us cherish, in hearts, and in sighs,
# The simple wonder of endless blue skies,
# For in each expanse, hope begins to soar,
# A reminder that magic lives evermore.

# %% [markdown]
# # 2、使用提示词模板

# %%
from langchain_core.prompts import ChatPromptTemplate

# 需要注意的一点是，这里需要指明具体的role，在这里是system和用户
prompt = ChatPromptTemplate.from_messages([
    ("system", "你是世界级的技术文档编写者"),
    ("user", "{input}")  # {input}为变量
])

# 我们可以把prompt和具体llm的调用和在一起。
chain = prompt | llm
message = chain.invoke({"input": "大模型中的LangChain是什么?"})
print(message)

# print(type(message))
# Out:
# content='LangChain 是一个用于构建与大语言模型（LLM）交互的应用程序的框架。它提供了一系列工具和组件，帮助开发者更方便地构建、管理和优化与语言模型的交互，以便实现更复杂的功能和应用场景。\n\n### LangChain 的核心概念和组件\n\n1. **链（Chains）**：\n   LangChain 中的“链”指的是将多个操作串联在一起的过程。这可以是一个简单的单一任务，如生成文本，也可以是多个步骤的复合任务，例如从数据库检索信息然后生成响应。\n\n2. **文档（Documents）**：\n   LangChain 提供了处理文档的工具，以便为语言模型提供上下文。文档可以是各种形式的文本，框架能够对其进行解析和管理。\n\n3. **记忆（Memory）**：\n   该框架支持在对话或交互中保持上下文信息，通过记忆组件，系统能够记住历史交互，从而提升响应的相关性和连贯性。\n\n4. **工具（Tools）**：\n   LangChain 支持多种工具集成，例如 API 调用、数据库查询等，以便语言模型能够访问实时数据并做出更复杂的决策。\n\n5. **代理（Agents）**：\n   代理是具有决策能力的模型，可以根据用户输入选择使用哪个工具或链来生成回应。\n\n6. **环境（Environments）**：\n   LangChain 提供了多种运行环境的支持，使得分布式任务和并发操作能够在不同的环境中顺利运行。\n\n### 典型的应用场景\n\n- **对话系统**：构建智能客服或虚拟助理。\n- **内容生成**：实现自动化文章写作、产品描述生成等。\n- **信息检索**：根据用户查询从数据库或互联网中提取相关信息并生成响应。\n- **代码助手**：辅助编程或代码生成的应用。\n\n### 结论\n\nLangChain 是一个强大的工具，适用于各种基于大语言模型的应用，它的设计目标是简化与语言模型的交互，使得开发者能够更加专注于业务逻辑和应用的创新。通过利用 LangChain，开发者可以更快地构建出高效、灵活和智能的应用程序。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tok
# ...

# %% [markdown]
# # 3、 使用输出解析器

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser,JsonOutputParser

# 初始化模型
llm = ChatOpenAI(model="gpt-4o-mini")

# 创建提示模板
prompt = ChatPromptTemplate.from_messages([
    ("system", "你是世界级的技术文档编写者。"),
    ("user", "{input}")
])

# 使用输出解析器
# output_parser = StrOutputParser()
output_parser = JsonOutputParser()

# 将其添加到上一个链中
# chain = prompt | llm
chain = prompt | llm | output_parser

# 调用它并提出同样的问题。答案是一个字符串，而不是ChatMessage
# chain.invoke({"input": "LangChain是什么?"})
chain.invoke({"input": "LangChain4J是什么? 用JSON格式回复，问题用question，回答用answer"})
# Out:
# {'question': 'LangChain4J是什么?',
#  'answer': 'LangChain4J是一个用于构建基于大语言模型（LLM）的应用程序的框架。它支持多种功能模块，如链式调用、数据序列化和插件扩展，旨在简化和加速开发流程，帮助开发者更有效地集成和利用大型语言模型的能力。'}

# %% [markdown]
# # 4、使用向量存储

# %%
# 导入和使用 WebBaseLoader
from langchain_community.document_loaders import WebBaseLoader
import bs4

loader = WebBaseLoader(
        web_path="https://www.utoronto.ca/news/geochemist-draws-billion-year-old-water-discovery-aid-green-energy-transition"
    )
docs = loader.load()
print(docs)

# 对于嵌入模型，这里通过 API调用
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")


from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 使用分割器分割文档
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
documents = text_splitter.split_documents(docs)
print(len(documents))
# 向量存储  embeddings 会将 documents 中的每个文本片段转换为向量，并将这些向量存储在 FAISS 向量数据库中
vector = FAISS.from_documents(documents, embeddings)
# Out:
# [Document(metadata={'source': 'https://www.utoronto.ca/news/geochemist-draws-billion-year-old-water-discovery-aid-green-energy-transition', 'title': 'Geochemist draws on billion-year-old water discovery to aid green energy transition | University of Toronto', 'description': 'Barbara Sherwood Lollar has spent more than 30 years studying deep, underground water and its surprisingly vast potential – from offering clues about potential life on other planets to locating valuable energy sources. A geochemist at the University of Toronto, she has found new tools to monitor the clean-up of contaminated groundwater, developed a better understanding of deep, subsurface gases and discovered what may be the world’s most ancient water – a find that drew the attention of NASA.', 'language': 'en'}, page_content="\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nGeochemist draws on billion-year-old water discovery to aid green energy transition | University of Toronto\n\n\n\n\n\n\n\n      Skip t
# ...

# %% [markdown]
# # 5、RAG(检索增强生成)

# %%
from langchain_core.prompts import PromptTemplate

retriever = vector.as_retriever()
retriever.search_kwargs = {"k": 3}
docs = retriever.invoke("who is Barbara Sherwood Lollar?")

# for i,doc in enumerate(docs):
#     print(f"⭐第{i+1}条规定：")
#     print(doc)

# 6.定义提示词模版
prompt_template = """
你是一个问答机器人。
你的任务是根据下述给定的已知信息回答用户问题。
确保你的回复完全依据下述已知信息。不要编造答案。
如果下述已知信息不足以回答用户的问题，请直接回复"我无法回答您的问题"。

已知信息:
{info}

用户问：
{question}

请用中文回答用户问题。
"""
# 7.得到提示词模版对象
template = PromptTemplate.from_template(prompt_template)

# 8.得到提示词对象
prompt = template.format(info=docs, question='who is Barbara Sherwood Lollar?')

## 9. 调用LLM
response = llm.invoke(prompt)
print(response.content)
# Out:
# 巴巴拉·谢伍德·洛拉（Barbara Sherwood Lollar）是多伦多大学的地球科学系教授，她花费了超过30年的时间研究深层地下水及其潜在的广泛应用，包括对其他行星上可能生命的线索和寻找有价值的能源。她发现了新的工具来监测受污染地下水的清理，发展了对深层地下气体的更好理解，并发现了可能是世界上最古老的水，这一发现引起了NASA的关注。她因其成就获得了众多杰出奖项，包括加拿大科学与工程的格哈德·赫兹贝格金奖和自然科学的基拉姆奖。

# %% [markdown]
# # 6、使用Agent

# %%
from langchain.tools.retriever import create_retriever_tool

# 检索器工具
retriever_tool = create_retriever_tool(
    retriever,
    "CivilCodeRetriever",
    "搜索有关中华人民共和国民法典的信息。关于中华人民共和国民法典的任何问题，您必须使用此工具!",
)

tools = [retriever_tool]

from langchain import hub
from langchain.agents import create_openai_functions_agent
from langchain.agents import AgentExecutor

# https://smith.langchain.com/hub
prompt = hub.pull("hwchase17/openai-functions-agent")

agent = create_openai_functions_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

# 运行代理
agent_executor.invoke({"input": "建设用地使用权是什么"})
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 from langchain.agents import create_retriever_tool
#       3 # 检索器工具
#       4 retriever_tool = create_retriever_tool(
#       5     retriever,
#       6     "CivilCodeRetriever",
#       7     "搜索有关中华人民共和国民法典的信息。关于中华人民共和国民法典的任何问题，您必须使用此工具!",
#       8 )
#
# ImportError: cannot import name 'create_retriever_tool' from 'langchain.agents' (C:\Users\KevinX\AppData\Local\miniconda3\envs\my_env1\Lib\site-packages\langchain\agents\__init__.py)
